# %%
#module = a file containing python code. May contain fuctions.classes ,etc.
#used with modular programming, which is to separate a program into parts
#You import the .py file
#import import_ipynb
from messages import hello,bye
#from messages import * #import all

help("modules")
hello()
bye()
# Out:
# Please wait a moment while I gather a list of all available modules...
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# 903778 WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa"
# 907850 INFO: generated new fontManager
# 909540 INFO: NumExpr defaulting to 8 threads.
# 911405 INFO: Could not import comtypes.gen, trying to create it.
# 911406 INFO: Created comtypes.gen directory: 'C:\Users\Eduardo\anaconda3\lib\site-packages\comtypes\gen'
# 911407 INFO: Writing __init__.py file: 'C:\Users\Eduardo\anaconda3\lib\site-packages\comtypes\gen\__init__.py'
# 911411 INFO: Using writeable comtypes cache directory: 'C:\Users\Eduardo\anaconda3\lib\site-packages\comtypes\gen'
# C:\Users\Eduardo\anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\Eduardo\anaconda3\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Update LANGUAGE_CODES (inside config/base.py) if a new translation has been added to Spyder
# 937444 INFO: QSS file sucessfuly loaded.
# 937446 INFO: Found application patches to be applied.
# 937446 WARNING: No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# C:\Users\Eduardo\anaconda3\lib\pkgutil.py:108: VisibleDeprecationWarning:
#
# zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
# Cython              colorcet            mmapfile            sndhdr
# IPython             colorsys            mmsystem            sniffio
# OpenSSL             commctrl            mock                snowballstemmer
# PIL                 compileall          modulefinder        socket
# PyInstaller         comtypes            mpmath              socketserver
# PyQt5               concurrent          msgpack             socks
# TBB                 conda               msilib              sockshandler
# __future__          conda_build         msvcrt              sortedcollections
# _abc                conda_content_trust multidict           sortedcontainers
# _aix_support        conda_env           multipledispatch    soupsieve
# _argon2_cffi_bindings conda_pack          multiprocessing     sphinx
# _ast                conda_package_handling munkres             spyder
# _asyncio            conda_token         mypy_extensions     spyder_kernels
# _bisect             conda_verify        nacl                sqlalchemy
# _black_version      configparser        navigator_updater   sqlite3
# _blake2             constantly          nbclassic           sre_compile
# _bootlocale         contextlib          nbclient            sre_constants
# _bootsubprocess     contextvars         nbconvert           sre_parse
# _bz2                cookiecutter        nbformat            ssl
# _cffi_backend       copy                nest_asyncio        sspi
# _codecs             copyreg             netbios             sspicon
# _codecs_cn          crypt               netrc               stack_data
# _codecs_hk          cryptography        networkx            stat
# _codecs_iso2022     cssselect           nltk                statistics
# _codecs_jp          csv                 nntplib             statsmodels
# _codecs_kr          ctypes              nose                string
# _codecs_tw          curl                notebook            stringprep
# _collections        curses              nt                  struct
# _collections_abc    cwp                 ntpath              subprocess
# _compat_pickle      cycler              ntsecuritycon       sunau
# _compression        cython              nturl2path          symbol
# _contextvars        cytoolz             numba               sympy
# _csv                daal4py             numbergen           symtable
# _ctypes             dask                numbers             sys
# _ctypes_test        dataclasses         numexpr             sysconfig
# _datetime           datashader          numpy               tables
# _decimal            datashape           numpydoc            tabnanny
# _distutils_hack     datetime            odbc                tabulate
# _elementtree        dateutil            olefile             tarfile
# _functools          dbi                 onedal              tbb
# _hashlib            dbm                 opcode              tblib
# _heapq              dde                 openpyxl            telnetlib
# _imp                debugpy             operator            tempfile
# _io                 decimal             optparse            tenacity
# _json               decorator           ordlookup           terminado
# _locale             defusedxml          os                  test
# _lsprof             diff_match_patch    packaging           test_pycosat
# _lzma               difflib             pandas              testpath
# _markupbase         dis                 pandocfilters       text_unidecode
# _md5                distributed         panel               textdistance
# _msi                distutils           param               textwrap
# _multibytecodec     doctest             paramiko            this
# _multiprocessing    docutils            parsel              threading
# _nsis               email               parser              threadpoolctl
# _opcode             encodings           parso               three_merge
# _operator           ensurepip           partd               tifffile
# _osx_support        entrypoints         past                time
# _overlapped         enum                pathlib             timeit
# _peg_parser         erfa                pathspec            timer
# _pickle             errno               patsy               tinycss
# _plotly_future_     et_xmlfile          pdb                 tkinter
# _plotly_utils       executing           pefile              tldextract
# _py_abc             fastjsonschema      pep8                tlz
# _pydecimal          faulthandler        perfmon             token
# _pyinstaller_hooks_contrib filecmp             peutils             tokenize
# _pyio               fileinput           pexpect             toml
# _pyrsistent_version filelock            pickle              tomli
# _pytest             flake8              pickleshare         toolz
# _queue              flask               pickletools         tornado
# _random             fnmatch             pip                 tqdm
# _sha1               fontTools           pipes               trace
# _sha256             formatter           pkg_resources       traceback
# _sha3               fractions           pkginfo             tracemalloc
# _sha512             frozenlist          pkgutil             traitlets
# _signal             fsspec              platform            tty
# _sitebuiltins       ftplib              plistlib            turtle
# _socket             functools           plotly              turtledemo
# _sqlite3            future              pluggy              twisted
# _sre                gc                  poplib              typed_ast
# _ssl                genericpath         posixpath           types
# _stat               gensim              poyo                typing
# _statistics         getopt              pprint              typing_extensions
# _string             getpass             profile             ujson
# _strptime           gettext             prometheus_client   unicodedata
# _struct             glob                prompt_toolkit      unidecode
# _symtable           glob2               protego             unittest
# _system_path        google_crc32c       pstats              urllib
# _testbuffer         graphlib            psutil              urllib3
# _testcapi           greenlet            pty                 uu
# _testconsole        grpc                ptyprocess          uuid
# _testimportmultiple gzip                pure_eval           venv
# _testinternalcapi   h5py                pvectorc            w3lib
# _testmultiphase     hamcrest            py                  warnings
# _thread             hashlib             py_compile          watchdog
# _threading_local    heapdict            pyasn1              wave
# _tkinter            heapq               pyasn1_modules      wcwidth
# _tracemalloc        hmac                pyclbr              weakref
# _uuid               holoviews           pycodestyle         webbrowser
# _warnings           html                pycosat             webencodings
# _weakref            http                pycparser           websocket
# _weakrefset         hvplot              pyct                werkzeug
# _win32sysloader     hyperlink           pycurl              wheel
# _winapi             idlelib             pydispatch          widgetsnbextension
# _winxptheme         idna                pydoc               win2kras
# _xxsubinterpreters  imagecodecs         pydoc_data          win32api
# _yaml               imageio             pydocstyle          win32clipboard
# _zoneinfo           imagesize           pyexpat             win32com
# abc                 imaplib             pyflakes            win32con
# adodbapi            imghdr              pygments            win32console
# afxres              imp                 pylab               win32cred
# aifc                import_ipynb        pylint              win32crypt
# aiohttp             importlib           pyls_spyder         win32cryptcon
# aiosignal           importlib_metadata  pylsp               win32ctypes
# alabaster           incremental         pylsp_black         win32event
# altgraph            inflection          pylsp_jsonrpc       win32evtlog
# anaconda_navigator  iniconfig           pyodbc              win32evtlogutil
# anaconda_project    inspect             pyparsing           win32file
# antigravity         intake              pyreadline          win32gui
# anyio               intervaltree        pyrsistent          win32gui_struct
# appdirs             io                  pytest              win32help
# argon2              ipaddress           pythoncom           win32inet
# argparse            ipykernel           pytz                win32inetcon
# array               ipykernel_launcher  pyviz_comms         win32job
# arrow               ipython_genutils    pywin               win32lz
# ast                 ipywidgets          pywin32_bootstrap   win32net
# astroid             isapi               pywin32_testutil    win32netcon
# astropy             isort               pywintypes          win32pdh
# asttokens           isympy              pywt                win32pdhquery
# async_timeout       itemadapter         pyximport           win32pdhutil
# asynchat            itemloaders         qdarkstyle          win32pipe
# asyncio             itertools           qstylizer           win32print
# asyncore            itsdangerous        qtawesome           win32process
# atexit              jdcal               qtconsole           win32profile
# atomicwrites        jedi                qtpy                win32ras
# attr                jinja2              queue               win32rcparser
# attrs               jinja2_time         queuelib            win32security
# audioop             jmespath            quopri              win32service
# automat             joblib              random              win32serviceutil
# autopep8            json                rasutil             win32timezone
# babel               json5               re                  win32trace
# backcall            jsonschema          readline            win32traceutil
# backports           jupyter             regcheck            win32transaction
# base64              jupyter_client      regex               win32ts
# bcrypt              jupyter_console     regutil             win32ui
# bdb                 jupyter_core        repo_cli            win32uiole
# binaryornot         jupyter_server      reprlib             win32verstamp
# binascii            jupyterlab          requests            win32wnet
# binhex              jupyterlab_plotly   requests_file       win_inet_pton
# binstar_client      jupyterlab_pygments rlcompleter         win_unicode_console
# bisect              jupyterlab_server   rope                wincertstore
# bitarray            jupyterlab_widgets  rsa                 winerror
# bkcharts            jwt                 rtree               winioctlcon
# black               keyring             ruamel_yaml         winnt
# blackd              keyword             run                 winperf
# bleach              kiwisolver          runpy               winpty
# blib2to3            lazy_object_proxy   s3transfer          winreg
# bokeh               lib2to3             sched               winsound
# boto3               libarchive          scipy               winxpgui
# botocore            libfuturize         scrapy              winxptheme
# bottleneck          libpasteurize       seaborn             wrapt
# brotli              lief                secrets             wsgiref
# bs4                 linecache           select              xarray
# builtins            llvmlite            selectors           xdrlib
# bz2                 locale              send2trash          xlrd
# cProfile            locket              service_identity    xlsxwriter
# cachetools          logging             servicemanager      xlwings
# calendar            lxml                setuptools          xml
# certifi             lzma                shelve              xmlrpc
# cffi                mailbox             shlex               xxsubtype
# cgi                 mailcap             shutil              yaml
# cgitb               markdown            signal              yapf
# chardet             markupsafe          sip                 yapftests
# charset_normalizer  marshal             sipconfig           yarl
# chunk               math                sipdistutils        zict
# click               matplotlib          site                zipapp
# cloudpickle         matplotlib_inline   six                 zipfile
# clyent              mccabe              skimage             zipimport
# cmath               menuinst            sklearn             zipp
# cmd                 mimetypes           sklearnex           zlib
# code                mistune             slugify             zmq
# codecs              mkl                 smart_open          zoneinfo
# codeop              mkl_fft             smtpd               zope
# collections         mkl_random          smtplib
# colorama            mmap                snappy
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# Hello!Have a nice day!
# Bye! Havwe a wonderful time!
